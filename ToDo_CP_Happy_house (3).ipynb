# %% [markdown]
# # If you happy and I know it you can enter my House
#
# You'll see how you can in a couple of hours build a deep learning algorithm.

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import h5py
from keras import layers
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.models import Model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Sequential

import pydot
from IPython.display import SVG


import keras.backend as K
K.set_image_data_format('channels_last')
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

# %%
def load_dataset(path_to_train, path_to_test):
    train_dataset = h5py.File(path_to_train)
    train_x = np.array(train_dataset['train_set_x'][:])
    train_y = np.array(train_dataset['train_set_y'][:])

    test_dataset = h5py.File(path_to_test)
    test_x = np.array(test_dataset['test_set_x'][:])
    test_y = np.array(test_dataset['test_set_y'][:])

    # y reshaped
    train_y = train_y.reshape((1, train_x.shape[0]))
    test_y = test_y.reshape((1, test_y.shape[0]))

    return train_x, train_y, test_x, test_y

# %% [markdown]
# This dataset can be used to solve the Happy House problem.
# Where, we allow a person to enter the house only if he/she is smiling!
# So, a smile detector!

# %% [markdown]
# ![Texte alternatif…](https://raw.githubusercontent.com/Kulbear/deep-learning-coursera/master/Convolutional%20Neural%20Networks/images/house-members.png)

# %% [markdown]
# Details of the "Happy" dataset:
#
# * Images are of shape (64,64,3)
# * Training: 600 pictures
# * Test: 150 pictures

# %% [markdown]
# # Load Dataset

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig = load_dataset("train_happy.h5","test_happy.h5")

# Normalize image vectors
X_train = X_train_orig/255.
X_test = X_test_orig/255.

# Reshape
Y_train = Y_train_orig.T
Y_test = Y_test_orig.T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 600
# number of test examples = 150
# X_train shape: (600, 64, 64, 3)
# Y_train shape: (600, 1)
# X_test shape: (150, 64, 64, 3)
# Y_test shape: (150, 1)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.

# %%
text_labels = ['sad', 'happy']

# %%
# Sample image from dataset
print("Image shape :",X_train_orig[10].shape)
print("",Y_train_orig[0][10])
print (text_labels[Y_train_orig[0][10]])
imshow(X_train_orig[10])
# Out:
# Image shape : (64, 64, 3)
#  0
# sad

# %% [markdown]
# # Building Model

# %% [markdown]
# _________________________________________________________________
#
# conv2d_3 (Conv2D)            (None, 64, 64, 32)        4736
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 32769
# _________________________________________________________________

# %%
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same',input_shape=X_train_orig[0].shape))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2,2)))    
model.add(Flatten())

# %%
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=["accuracy"])

# %%
from keras.callbacks import EarlyStopping

# %%
mycallbacks = [EarlyStopping(monitor='val_loss', patience=2)]

# %%
history_model = model.fit(X_train, Y_train,epochs=50, batch_size=64,  callbacks = mycallbacks)
# Out:
# Epoch 1/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0422 - accuracy: 0.9850WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 364ms/step - loss: 0.0422 - accuracy: 0.9850
# Epoch 2/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0432 - accuracy: 0.9833WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 363ms/step - loss: 0.0432 - accuracy: 0.9833
# Epoch 3/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0400 - accuracy: 0.9867WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 367ms/step - loss: 0.0400 - accuracy: 0.9867
# Epoch 4/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 0.9917WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 362ms/step - loss: 0.0317 - accuracy: 0.9917
# Epoch 5/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0296 - accuracy: 0.9933WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 366ms/step - loss: 0.0296 - accuracy: 0.9933
# Epoch 6/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9917WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 362ms/step - loss: 0.0283 - accuracy: 0.9917
# Epoch 7/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.9917WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 366ms/step - loss: 0.0285 - accuracy: 0.9917
# Epoch 8/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0329 - accuracy: 0.9883WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 366ms/step - loss: 0.0329 - accuracy: 0.9883
# Epoch 9/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0296 - accuracy: 0.9900WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 363ms/step - loss: 0.0296 - accuracy: 0.9900
# Epoch 10/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9917WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 365ms/step - loss: 0.0208 - accuracy: 0.9917
# Epoch 11/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 0.9950WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 364ms/step - loss: 0.0212 - accuracy: 0.9950
# Epoch 12/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9900WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 360ms/step - loss: 0.0274 - accuracy: 0.9900
# Epoch 13/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9950WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 367ms/step - loss: 0.0256 - accuracy: 0.9950
# Epoch 14/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.9917WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 365ms/step - loss: 0.0260 - accuracy: 0.9917
# Epoch 15/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9917WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 367ms/step - loss: 0.0245 - accuracy: 0.9917
# Epoch 16/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9883WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 365ms/step - loss: 0.0229 - accuracy: 0.9883
# Epoch 17/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9983WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 364ms/step - loss: 0.0159 - accuracy: 0.9983
# Epoch 18/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 0.9967WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 367ms/step - loss: 0.0168 - accuracy: 0.9967
# Epoch 19/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9950WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 368ms/step - loss: 0.0156 - accuracy: 0.9950
# Epoch 20/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 0.9933WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0140 - accuracy: 0.9933
# Epoch 21/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 370ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 22/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9883WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 371ms/step - loss: 0.0349 - accuracy: 0.9883
# Epoch 23/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9967WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 365ms/step - loss: 0.0142 - accuracy: 0.9967
# Epoch 24/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9983WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 364ms/step - loss: 0.0113 - accuracy: 0.9983
# Epoch 25/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9983WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 366ms/step - loss: 0.0100 - accuracy: 0.9983
# Epoch 26/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.9967WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 366ms/step - loss: 0.0150 - accuracy: 0.9967
# Epoch 27/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 0.9950WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 365ms/step - loss: 0.0168 - accuracy: 0.9950
# Epoch 28/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9967WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 367ms/step - loss: 0.0125 - accuracy: 0.9967
# Epoch 29/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9967WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 364ms/step - loss: 0.0143 - accuracy: 0.9967
# Epoch 30/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9967WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 366ms/step - loss: 0.0137 - accuracy: 0.9967
# Epoch 31/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9950WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 364ms/step - loss: 0.0186 - accuracy: 0.9950
# Epoch 32/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9950WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 365ms/step - loss: 0.0107 - accuracy: 0.9950
# Epoch 33/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9967WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 367ms/step - loss: 0.0118 - accuracy: 0.9967
# Epoch 34/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 366ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 35/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 0.9967WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 365ms/step - loss: 0.0111 - accuracy: 0.9967
# Epoch 36/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9933WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 371ms/step - loss: 0.0153 - accuracy: 0.9933
# Epoch 37/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9983WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 366ms/step - loss: 0.0103 - accuracy: 0.9983
# Epoch 38/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9983WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 367ms/step - loss: 0.0062 - accuracy: 0.9983
# Epoch 39/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9983WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 365ms/step - loss: 0.0056 - accuracy: 0.9983
# Epoch 40/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9950WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 367ms/step - loss: 0.0113 - accuracy: 0.9950
# Epoch 41/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 0.9950WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 366ms/step - loss: 0.0104 - accuracy: 0.9950
# Epoch 42/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 0.9983WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 365ms/step - loss: 0.0172 - accuracy: 0.9983
# Epoch 43/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9950WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 369ms/step - loss: 0.0118 - accuracy: 0.9950
# Epoch 44/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0217 - accuracy: 0.9933WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 366ms/step - loss: 0.0217 - accuracy: 0.9933
# Epoch 45/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0499 - accuracy: 0.9750WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 368ms/step - loss: 0.0499 - accuracy: 0.9750
# Epoch 46/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0484 - accuracy: 0.9833WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 367ms/step - loss: 0.0484 - accuracy: 0.9833
# Epoch 47/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9950WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 365ms/step - loss: 0.0185 - accuracy: 0.9950
# Epoch 48/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 0.9967WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 365ms/step - loss: 0.0099 - accuracy: 0.9967
# Epoch 49/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9983WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 364ms/step - loss: 0.0051 - accuracy: 0.9983
# Epoch 50/50
# 10/10 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 10/10 [==============================] - 4s 366ms/step - loss: 0.0048 - accuracy: 1.0000

# %% [markdown]
# # Evaluate / Test

# %%
train_accuracy = history_model.history['accuracy']
train_loss = history_model.history['loss']

count = range(len(train_accuracy))
plt.plot(count, train_accuracy, label='Training accuracy')
plt.plot(count, train_loss, label='Training Loss')
plt.title('epochs vs Training Loss')
plt.legend()

# %%
test_logits = model.predict(X_test_orig)

# %%
plt.figure(figsize=(20,20))
for i in range(50):
    plt.subplot(10,10,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    
    img_index = np.random.randint(0, 100)
    plt.imshow(X_test_orig[img_index], cmap=plt.cm.gray)
    
    actual_label = int(Y_test_orig[0][img_index])
    predicted_label = int(test_logits[img_index])
    
    plt.xlabel("Actual: {} ({})\n Predicted: {} ({})".format(
        actual_label, text_labels[actual_label], predicted_label, text_labels[predicted_label]
    ))
    
plt.tight_layout()
plt.show()

# %% [markdown]
# Evaluate Test set

# %%
preds = model.evaluate(X_test, Y_test)
print()
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0961 - accuracy: 0.9733
#
# Loss = 0.0960840955376625
# Test Accuracy = 0.9733333587646484

# %% [markdown]
# Confusion Matrix

# %%
y_pred = model.predict(X_test)
y_pred[y_pred < 0.5] = 0
y_pred[y_pred >= 0.5] = 1
cm = confusion_matrix(Y_test, y_pred)
sns.set(font_scale=1.4) 
sns.heatmap(cm, annot=True, annot_kws={"size": 20}, cmap="YlGn",linewidths=0.5) 
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %% [markdown]
# # Note
#
# Before you submit your work
#
# * You should compare different optimizers
#
# ---
#
# * Display images with Predicted & expected labels (Happy-sad)
